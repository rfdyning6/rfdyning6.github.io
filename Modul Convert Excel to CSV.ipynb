# %% [markdown]
# **Membuat Modul Converting Excel to CSV**
#
# Reff : https://datatofish.com/excel-to-csv-python/ ; https://docs.python.org/3/library/tk.html

# %%
# !cd drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive/MyDrive/Dataset/Printing/

# %%
import pandas as pd

read_file = pd.read_excel (r'/content/drive/MyDrive/Dataset/Printing/pi5.xlsx')
read_file.to_csv (r'/content/drive/MyDrive/Dataset/Printing/pr01_temp4.csv', index = None, header=True)
